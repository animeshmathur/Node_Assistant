# %%
import pandas as pd

# %%
text_commands = pd.read_csv('./text_commands.csv')

# %%
text_commands
# Out:
#                                                  Text   Action_Key
# 0                                            npm list     npm_list
# 1                               list the dependencies     npm_list
# 2                list packages which are there in app     npm_list
# 3                     what are the dependent packages     npm_list
# 4                                execute list command     npm_list
# 5                     is there any dependent package?     npm_list
# 6           what dependencies does this project have?     npm_list
# 7                 list out packages dependent to this     npm_list
# 8          Provide me information on packages on this     npm_list
# 9                   which all packages are installed?     npm_list
# 10        I want to know which packages are dependent     npm_list
# 11                tell me what are dependent packages     npm_list
# 12         can you tell me what are the dependencies?     npm_list
# ...
